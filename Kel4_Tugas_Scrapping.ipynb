# %% [markdown]
# Scarpping HTTP detik.com

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "https://www.detik.com/"
html = requests.get(url).text
soup = BeautifulSoup(html, "html.parser")

data = []
for a in soup.select("div.box.cb-mostpop a[href]"):
    title = a.get_text(strip=True)
    link = a["href"]
    if title and "detik.com" in link:
        data.append({"title": title, "url": link})
        print("-", title, "->", link)
if data:
    df = pd.DataFrame(data)
    df.to_csv("BeritaDetik_Terpopuler.csv", index=False)
# Out:
# - Nasib Kementerian BUMN Usai Prabowo 'Reshuffle' Erick Thohir -> https://finance.detik.com/berita-ekonomi-bisnis/d-8117275/nasib-kementerian-bumn-usai-prabowo-reshuffle-erick-thohir
# - Hasil Liga Champions Tadi Malam: PSG, Bayern, Inter, Liverpool Menang -> https://sport.detik.com/sepakbola/uefa/d-8117568/hasil-liga-champions-tadi-malam-psg-bayern-inter-liverpool-menang
# - Cerita Bima Dilaporkan Hilang saat Demo di Kwitang, Ternyata Jualan di Malang -> https://news.detik.com/berita/d-8117574/cerita-bima-dilaporkan-hilang-saat-demo-di-kwitang-ternyata-jualan-di-malang
# - The Reds Lagi-lagi Menang Dramatis -> https://sport.detik.com/sepakbola/uefa/d-8117569/the-reds-lagi-lagi-menang-dramatis
# - Terungkap soal Kartu Nama Kacab Bank Ilham yang Berujung Petaka -> https://news.detik.com/berita/d-8117593/terungkap-soal-kartu-nama-kacab-bank-ilham-yang-berujung-petaka
# - Lihat Selengkapnya -> https://www.detik.com/terpopuler

# %% [markdown]
# Scrapping API Youtube

# %%
import pandas as pd
import time
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
import json

API_KEY = "AIzaSyDEN9rgkf9JRPycOpa_DMJE1mkPEQAIikA"
VIDEO_ID = 'uNgCzh-WAx8'

def get_video_comments_as_df(api_key, video_id, limit=100):
    all_comments_list = []

    try:
        youtube = build('youtube', 'v3', developerKey=api_key)
        request = youtube.commentThreads().list(
            part='snippet',
            videoId=video_id,
            maxResults=min(limit, 100))

        while request:
            response = request.execute()

            for item in response['items']:
                comment = item['snippet']['topLevelComment']['snippet']
                all_comments_list.append({
                    'author': comment['authorDisplayName'],
                    'text': comment['textDisplay'],
                    'published_at': comment['publishedAt']})

                if len(all_comments_list) >= limit:
                    return pd.DataFrame(all_comments_list)

            if 'nextPageToken' in response:
                 request = youtube.commentThreads().list_next(request, response)
                 time.sleep(1)
            else:
                break

        return pd.DataFrame(all_comments_list)

    except HttpError as e:
        print(f"Terjadi error saat memanggil API: {e}")
        return pd.DataFrame()
    except Exception as e:
        print(f"Terjadi error lain: {e}")
        return pd.DataFrame()

if __name__ == "__main__":
    COMMENT_LIMIT = 50

    print(f"Mengambil {COMMENT_LIMIT} komentar dari video ID: {VIDEO_ID}...")
    comments_df = get_video_comments_as_df(API_KEY, VIDEO_ID, limit=COMMENT_LIMIT)
    if not comments_df.empty:
        print(f"Berhasil mendapatkan {len(comments_df)} komentar.")
        print(comments_df)

    else:
        print("\nGagal mendapatkan data atau tidak ada komentar")
# Out:
# Mengambil 50 komentar dari video ID: uNgCzh-WAx8...
# Berhasil mendapatkan 50 komentar.
#                      author  \
# 0            @BfjadjhNfsidj
# 1     @faizmuhrizalofficial
# 2      @rohmatsupriatna9205
# 3              @snaurorraa.
# 4   @LyievianapasaymaShilta
# 5        @AlfianSaputra-s3l
# 6          @dinkzpublic2740
# 7                 @Xeran.07
# 8          @cucuhapsari5869
# 9                 @Ifah-x8i
# 10              @ServasDhae
# 11                @Xeran.07
# 12     @hermawansusanto1169
# 13          @AbdulSukma-m4d
# 14             @YuliWin-s3h
# 15               @reeya-v7s
# 16       @MillaSulistiawati
# 17        @KendrickClaycomb
# 18                @cntaayy8
# 19                 @urfyizr
# 20                @aksballs
# 21                @aksballs
# 22     @deniislahdirihaiden
# 23        @RaffaMohamad-l2e
# 24        @MasniMasni-nw5ks
# 25             @SenseiDhann
# 26        @MulatiyuliMulati
# 27       @halizahchunli2048
# 28                @aksballs
# 29                @aksballs
# 30                  @xjanx2
# 31             @diahprayoni
# 32          @JimarJimar-i6j
# 33           @AlifShahAidid
# 34      @AqillahAprilliyani
# 35           @BonBoni-ob5kz
# 36          @fajarkayla8575
# 37                 @DuoBiru
# 38         @ayolahsubscribe
# 39       @bregancraft-rm6vt
# 40      @SitiMardiyatun-x1d
# 41       @putriaprillia-h4u
# 42              @SeanHassan
# 43                 @Krisn_S
# 44        @sainahsainah6249
# 45          @DelaAzalia-g1e
# 46           @MurniaNia-z3x
# 47        @KadekWardani-z8i
# 48           @hirihyuga2239
# 49                @sukriIla
#
#                                                  text          published_at
# 0         Dual-language captions expand global reach.  2025-09-18T00:40:41Z
# 1   siapa yang nonton video ini karena suka nasi g...  2025-09-18T00:31:37Z
# 2                                  Tiba tiba jumcsar😢  2025-09-17T18:54:27Z
# 3                           endingnya ngakak muter2 😂  2025-09-17T18:07:30Z
# 4                                         Sama bang:)  2025-09-17T14:12:51Z
# 5     Kok di Palembang harga nasi goreng cuma 10 ribu  2025-09-17T13:09:32Z
# 6             Banyak gaya viktor rsakan terajang nya🤣  2025-09-17T11:43:13Z
# 7   <a href="https://www.youtube.com/watch?v=uNgCz...  2025-09-17T08:06:29Z
# 8   Bag game mabar ama kawan kawan pisahin gua suk...  2025-09-17T07:54:53Z
# 9                  Bang main game deesa meraung kidul  2025-09-17T07:54:43Z
# 10  Banggg baru mau nonton ampe abiss malah aku le...  2025-09-17T07:46:53Z
# 11  <a href="https://www.youtube.com/watch?v=uNgCz...  2025-09-17T07:39:01Z
# 12                                             000000  2025-09-17T07:31:50Z
# 13                                    A♂️🦻 aku ihsanz  2025-09-17T06:07:54Z
